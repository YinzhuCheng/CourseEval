# %% [markdown]
# # Notebook Runner MVP demo
#
# This notebook is used to validate the upload -> queue -> Docker execution flow.

# %%
print("Hello from the notebook runner")
total = sum(range(1, 6))
print(f"1 + 2 + 3 + 4 + 5 = {total}")
total
